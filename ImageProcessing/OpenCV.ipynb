# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('/home/sticker/Desktop/All/photo.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1683, 1300, 3)

# %%
plt.imshow(img)
plt.show()

# %%
#RGB 
#InopenCV blue green red  this function is used to convert the BGR into any format 
fix_img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)
plt.show()

# %%
#read an image into grey scale form
img_gray = cv2.imread('/home/sticker/Desktop/All/photo.jpg',cv2.IMREAD_GRAYSCALE)
img_gray.min()
# Out:
# 0

# %%
#cmap gray is used because because of BGR form it is not in blcak and white form so we use cmap='gray' to convert it
plt.imshow(img_gray,cmap='gray')
plt.show()

# %%
#Image resizeing
